# %%
! pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycaret
#   Downloading pycaret-3.0.0-py3-none-any.whl (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 KB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.7.1)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.1.2)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.2.2)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (4.65.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (6.0.0)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.10.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 20.4 MB/s eta 0:00:00
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.56.4)
# Collecting sktime>=0.16.1
#   Downloading sktime-0.16.1-py3-none-any.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 44.3 MB/s eta 0:00:00
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.10.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.7.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.9.4)
# Collecting pyod>=1.0.8
#   Downloading pyod-1.0.9.tar.gz (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 KB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (3.3.5)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting schemdraw>=0.14
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (5.13.1)
# Collecting plotly-resampler>=0.8.3.1
#   Downloading plotly_resampler-0.8.3.2.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 KB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (7.9.0)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 53.1 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.9/dist-packages (from pycaret) (7.7.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (0.13.5)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.22.4)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pycaret) (1.4.4)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.9/dist-packages (from pycaret) (2.27.1)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from deprecation>=2.1.0->pycaret) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn>=0.8.1->pycaret) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.15.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (63.4.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.6 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.6.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=3.0.0->pycaret) (0.40.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (4.39.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.0->pycaret) (8.4.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat>=4.2.0->pycaret) (4.3.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Collecting jupyter-dash>=0.4.2
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.8.8-cp39-cp39-manylinux_2_28_x86_64.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 15.2 MB/s eta 0:00:00
# Collecting dash<3.0.0,>=2.2.0
#   Downloading dash-2.9.1-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 88.5 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.1/185.1 KB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.33)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.15)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.1->pycaret) (2.0.12)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.9/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.15.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.2.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.16.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (23.2.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.9/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.23.6)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.11.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Building wheels for collected packages: plotly-resampler, pyod
#   Building wheel for plotly-resampler (pyproject.toml) ... done
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3.2-cp39-cp39-manylinux_2_31_x86_64.whl size=75058 sha256=622c9ba31a4fa8255cdfbb8f9c3842c91c2ae02f5efd863b619b023e9772e339
#   Stored in directory: /root/.cache/pip/wheels/9e/36/06/4c11e300918011376af149098621ec7ebe06d8256566d43d51
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.9-py3-none-any.whl size=184112 sha256=1066bf54db15cad69a85624929702d1485ea365861e9775dbe8bda1827b60258
#   Stored in directory: /root/.cache/pip/wheels/1b/9c/b8/9759d7cc64a1e01bb9872ade80cb7db445ccf506e083325106
# Successfully built plotly-resampler pyod
# Installing collected packages: trace-updater, kaleido, dash-table, dash-html-components, dash-core-components, xxhash, wurlitzer, schemdraw, retrying, orjson, joblib, jedi, deprecation, deprecated, ansi2html, sktime, scikit-plot, pyod, dash, pmdarima, jupyter-dash, category-encoders, tbats, plotly-resampler, pycaret
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# Successfully installed ansi2html-1.8.0 category-encoders-2.6.0 dash-2.9.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.13 deprecation-2.1.0 jedi-0.18.2 joblib-1.2.0 jupyter-dash-0.4.2 kaleido-0.2.1 orjson-3.8.8 plotly-resampler-0.8.3.2 pmdarima-2.0.3 pycaret-3.0.0 pyod-1.0.9 retrying-1.3.4 schemdraw-0.15 scikit-plot-0.3.7 sktime-0.16.1 tbats-1.1.2 trace-updater-0.0.9 wurlitzer-3.0.3 xxhash-3.2.0

# %%
! pip install mlflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mlflow
#   Downloading mlflow-2.2.2-py3-none-any.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 55.7 MB/s eta 0:00:00
# Collecting gunicorn<21
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (3.19.6)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 KB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (8.1.3)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.9/dist-packages (from mlflow) (2.2.1)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.9/dist-packages (from mlflow) (1.4.4)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.9/dist-packages (from mlflow) (2.2.3)
# Requirement already satisfied: packaging<24 in /usr/local/lib/python3.9/dist-packages (from mlflow) (23.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.9/dist-packages (from mlflow) (1.2.2)
# Requirement already satisfied: pytz<2023 in /usr/local/lib/python3.9/dist-packages (from mlflow) (2022.7.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.9/dist-packages (from mlflow) (2.27.1)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (9.0.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (0.4.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (6.0.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.9/dist-packages (from mlflow) (1.22.4)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.9/dist-packages (from mlflow) (1.10.1)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.9/dist-packages (from mlflow) (3.7.1)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.9/dist-packages (from mlflow) (0.4)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.9/dist-packages (from mlflow) (3.1.2)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.7 MB/s eta 0:00:00
# Collecting alembic<2
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.3 MB/s eta 0:00:00
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.5.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.9/dist-packages (from mlflow) (3.4.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.9/dist-packages (from mlflow) (6.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow) (1.4.46)
# Collecting shap<1,>=0.40
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic<2->mlflow) (4.5.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 8.9 MB/s eta 0:00:00
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow) (1.5.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow) (1.26.15)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow) (2.2.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.9/dist-packages (from gunicorn<21->mlflow) (63.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2<4,>=2.11->mlflow) (2.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.17.3->mlflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.17.3->mlflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<2->mlflow) (3.1.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap<1,>=0.40->mlflow) (0.56.4)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.9/dist-packages (from shap<1,>=0.40->mlflow) (4.65.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap<1,>=0.40->mlflow) (0.39.1)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.5-py3-none-any.whl size=143016 sha256=d2c838952bb6f43e4b8b2311c0e22858e076669ea18ba24d3343e3cef05b601d
#   Stored in directory: /root/.cache/pip/wheels/d1/ac/b1/2c75e46c6ffb00ed09b3c94577a1ea387b75289a2ee04f247d
# Successfully built databricks-cli
# Installing collected packages: smmap, slicer, querystring-parser, pyjwt, Mako, gunicorn, gitdb, docker, databricks-cli, alembic, shap, gitpython, mlflow
# Successfully installed Mako-1.2.4 alembic-1.10.2 databricks-cli-0.17.5 docker-6.0.1 gitdb-4.0.10 gitpython-3.1.31 gunicorn-20.1.0 mlflow-2.2.2 pyjwt-2.6.0 querystring-parser-1.2.4 shap-0.41.0 slicer-0.0.7 smmap-5.0.0

# %%
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
import pandas as pd 
data = pd.read_csv('creditcard.csv')

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Class', session_id=123, log_experiment=True, experiment_name='test1')
# Out:
# <style type="text/css">
# #T_8f983_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8f983" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f983_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8f983_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f983_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f983_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8f983_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f983_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8f983_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f983_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8f983_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f983_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8f983_row3_col1" class="data row3 col1" >(284807, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f983_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8f983_row4_col1" class="data row4 col1" >(284807, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f983_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8f983_row5_col1" class="data row5 col1" >(199364, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f983_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8f983_row6_col1" class="data row6 col1" >(85443, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f983_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8f983_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8f983_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_8f983_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8f983_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_8f983_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8f983_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_8f983_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8f983_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_8f983_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8f983_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_8f983_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8f983_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_8f983_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8f983_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_8f983_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8f983_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_8f983_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8f983_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_8f983_row16_col1" class="data row16 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8f983_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_8f983_row17_col1" class="data row17 col1" >test1</td>
#     </tr>
#     <tr>
#       <th id="T_8f983_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8f983_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_8f983_row18_col1" class="data row18 col1" >8693</td>
#     </tr>
#   </tbody>
# </table>
# 2023/03/21 23:04:35 INFO mlflow.tracking.fluent: Experiment with name 'test1' does not exist. Creating a new experiment.

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ff89a th {
#   text-align: left;
# }
# #T_ff89a_row0_col0, #T_ff89a_row0_col2, #T_ff89a_row0_col3, #T_ff89a_row1_col0, #T_ff89a_row1_col2, #T_ff89a_row1_col3, #T_ff89a_row1_col4, #T_ff89a_row1_col5, #T_ff89a_row1_col6, #T_ff89a_row1_col7, #T_ff89a_row2_col0, #T_ff89a_row2_col3, #T_ff89a_row2_col4, #T_ff89a_row2_col5, #T_ff89a_row2_col6, #T_ff89a_row2_col7, #T_ff89a_row3_col0, #T_ff89a_row3_col1, #T_ff89a_row3_col2, #T_ff89a_row3_col3, #T_ff89a_row3_col4, #T_ff89a_row3_col5, #T_ff89a_row3_col6, #T_ff89a_row3_col7, #T_ff89a_row4_col0, #T_ff89a_row4_col1, #T_ff89a_row4_col2, #T_ff89a_row4_col3, #T_ff89a_row4_col4, #T_ff89a_row4_col5, #T_ff89a_row4_col6, #T_ff89a_row4_col7, #T_ff89a_row5_col0, #T_ff89a_row5_col1, #T_ff89a_row5_col2, #T_ff89a_row5_col3, #T_ff89a_row5_col4, #T_ff89a_row5_col5, #T_ff89a_row5_col6, #T_ff89a_row5_col7, #T_ff89a_row6_col0, #T_ff89a_row6_col1, #T_ff89a_row6_col2, #T_ff89a_row6_col3, #T_ff89a_row6_col4, #T_ff89a_row6_col5, #T_ff89a_row6_col6, #T_ff89a_row6_col7, #T_ff89a_row7_col0, #T_ff89a_row7_col1, #T_ff89a_row7_col2, #T_ff89a_row7_col3, #T_ff89a_row7_col4, #T_ff89a_row7_col5, #T_ff89a_row7_col6, #T_ff89a_row7_col7, #T_ff89a_row8_col0, #T_ff89a_row8_col1, #T_ff89a_row8_col2, #T_ff89a_row8_col3, #T_ff89a_row8_col4, #T_ff89a_row8_col5, #T_ff89a_row8_col6, #T_ff89a_row8_col7, #T_ff89a_row9_col0, #T_ff89a_row9_col1, #T_ff89a_row9_col2, #T_ff89a_row9_col3, #T_ff89a_row9_col4, #T_ff89a_row9_col5, #T_ff89a_row9_col6, #T_ff89a_row9_col7, #T_ff89a_row10_col0, #T_ff89a_row10_col1, #T_ff89a_row10_col2, #T_ff89a_row10_col3, #T_ff89a_row10_col4, #T_ff89a_row10_col5, #T_ff89a_row10_col6, #T_ff89a_row10_col7, #T_ff89a_row11_col0, #T_ff89a_row11_col1, #T_ff89a_row11_col2, #T_ff89a_row11_col3, #T_ff89a_row11_col4, #T_ff89a_row11_col5, #T_ff89a_row11_col6, #T_ff89a_row11_col7, #T_ff89a_row12_col0, #T_ff89a_row12_col1, #T_ff89a_row12_col2, #T_ff89a_row12_col3, #T_ff89a_row12_col4, #T_ff89a_row12_col5, #T_ff89a_row12_col6, #T_ff89a_row12_col7, #T_ff89a_row13_col0, #T_ff89a_row13_col1, #T_ff89a_row13_col2, #T_ff89a_row13_col3, #T_ff89a_row13_col4, #T_ff89a_row13_col5, #T_ff89a_row13_col6, #T_ff89a_row13_col7, #T_ff89a_row14_col0, #T_ff89a_row14_col1, #T_ff89a_row14_col2, #T_ff89a_row14_col4, #T_ff89a_row14_col5, #T_ff89a_row14_col6, #T_ff89a_row14_col7 {
#   text-align: left;
# }
# #T_ff89a_row0_col1, #T_ff89a_row0_col4, #T_ff89a_row0_col5, #T_ff89a_row0_col6, #T_ff89a_row0_col7, #T_ff89a_row1_col1, #T_ff89a_row2_col1, #T_ff89a_row2_col2, #T_ff89a_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff89a_row0_col8, #T_ff89a_row1_col8, #T_ff89a_row2_col8, #T_ff89a_row3_col8, #T_ff89a_row4_col8, #T_ff89a_row5_col8, #T_ff89a_row6_col8, #T_ff89a_row7_col8, #T_ff89a_row8_col8, #T_ff89a_row9_col8, #T_ff89a_row11_col8, #T_ff89a_row12_col8, #T_ff89a_row13_col8, #T_ff89a_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff89a_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff89a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff89a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff89a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff89a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff89a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff89a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff89a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff89a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff89a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ff89a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff89a_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_ff89a_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_ff89a_row0_col1" class="data row0 col1" >0.9996</td>
#       <td id="T_ff89a_row0_col2" class="data row0 col2" >0.9566</td>
#       <td id="T_ff89a_row0_col3" class="data row0 col3" >0.7969</td>
#       <td id="T_ff89a_row0_col4" class="data row0 col4" >0.9528</td>
#       <td id="T_ff89a_row0_col5" class="data row0 col5" >0.8668</td>
#       <td id="T_ff89a_row0_col6" class="data row0 col6" >0.8666</td>
#       <td id="T_ff89a_row0_col7" class="data row0 col7" >0.8706</td>
#       <td id="T_ff89a_row0_col8" class="data row0 col8" >169.0070</td>
#     </tr>
#     <tr>
#       <th id="T_ff89a_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_ff89a_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_ff89a_row1_col1" class="data row1 col1" >0.9996</td>
#       <td id="T_ff89a_row1_col2" class="data row1 col2" >0.9595</td>
#       <td id="T_ff89a_row1_col3" class="data row1 col3" >0.7911</td>
#       <td id="T_ff89a_row1_col4" class="data row1 col4" >0.9456</td>
#       <td id="T_ff89a_row1_col5" class="data row1 col5" >0.8601</td>
#       <td id="T_ff89a_row1_col6" class="data row1 col6" >0.8599</td>
#       <td id="T_ff89a_row1_col7" class="data row1 col7" >0.8640</td>
#       <td id="T_ff89a_row1_col8" class="data row1 col8" >21.2700</td>
#     </tr>
#     <tr>
#       <th id="T_ff89a_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_ff89a_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff89a_row2_col1" class="data row2 col1" >0.9996</td>
#       <td id="T_ff89a_row2_col2" class="data row2 col2" >0.9827</td>
#       <td id="T_ff89a_row2_col3" class="data row2 col3" >0.8024</td>
#       <td id="T_ff89a_row2_col4" class="data row2 col4" >0.9371</td>
#       <td id="T_ff89a_row2_col5" class="data row2 col5" >0.8641</td>
#       <td id="T_ff89a_row2_col6" class="data row2 col6" >0.8638</td>
#       <td id="T_ff89a_row2_col7" class="data row2 col7" >0.8667</td>
#       <td id="T_ff89a_row2_col8" class="data row2 col8" >103.9080</td>
#     </tr>
#     <tr>
#       <th id="T_ff89a_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_ff89a_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ff89a_row3_col1" class="data row3 col1" >0.9994</td>
#       <td id="T_ff89a_row3_col2" class="data row3 col2" >0.9085</td>
#       <td id="T_ff89a_row3_col3" class="data row3 col3" >0.7795</td>
#       <td id="T_ff89a_row3_col4" class="data row3 col4" >0.8771</td>
#       <td id="T_ff89a_row3_col5" class="data row3 col5" >0.8240</td>
#       <td id="T_ff89a_row3_col6" class="data row3 col6" >0.8237</td>
#       <td id="T_ff89a_row3_col7" class="data row3 col7" >0.8258</td>
#       <td id="T_ff89a_row3_col8" class="data row3 col8" >1.5380</td>
#     </tr>
#     <tr>
#       <th id="T_ff89a_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_ff89a_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_ff89a_row4_col1" class="data row4 col1" >0.9992</td>
#       <td id="T_ff89a_row4_col2" class="data row4 col2" >0.9551</td>
#       <td id="T_ff89a_row4_col3" class="data row4 col3" >0.6395</td>
#       <td id="T_ff89a_row4_col4" class="data row4 col4" >0.8517</td>
#       <td id="T_ff89a_row4_col5" class="data row4 col5" >0.7284</td>
#       <td id="T_ff89a_row4_col6" class="data row4 col6" >0.7280</td>
#       <td id="T_ff89a_row4_col7" class="data row4 col7" >0.7366</td>
#       <td id="T_ff89a_row4_col8" class="data row4 col8" >6.9220</td>
#     </tr>
#     <tr>
#       <th id="T_ff89a_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_ff89a_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_ff89a_row5_col1" class="data row5 col1" >0.9992</td>
#       <td id="T_ff89a_row5_col2" class="data row5 col2" >0.9804</td>
#       <td id="T_ff89a_row5_col3" class="data row5 col3" >0.7035</td>
#       <td id="T_ff89a_row5_col4" class="data row5 col4" >0.8268</td>
#       <t
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
